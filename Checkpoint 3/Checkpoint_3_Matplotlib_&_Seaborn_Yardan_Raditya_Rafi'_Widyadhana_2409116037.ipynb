# %% [markdown]
# **Student Performance Dataset - Analisis performa belajar siswa berdasarkan data yang ada untuk menentukan strategi pembelajaran siswa**
#
# **SUMBER DATASET:**
# https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset
#
# dataset ini berisi informasi lengkap tentang 2.392 siswa sekolah menengah, yang merinci demografi, kebiasaan belajar, keterlibatan orang tua, kegiatan ekstrakurikuler, dan prestasi akademik mereka. Variabel target, GradeClass, mengklasifikasikan nilai siswa ke dalam kategori yang berbeda, sehingga menyediakan kumpulan data yang kuat untuk penelitian pendidikan, pemodelan prediktif, dan analisis statistik.

# %% [markdown]
# # **Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ## **Membaca Data**

# %%
df = pd.read_csv("/content/student_performance_dataset.csv")

df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %% [markdown]
# ## **Bar Chart**

# %%
# Set ukuran figure
plt.figure(figsize=(8, 5))

# Plot Bar Chart
sns.countplot(x="LearningStrategy", data=df, palette="Blues_r")

# Tambahkan judul dan label
plt.title("Distribusi Strategi Pembelajaran Siswa", fontsize=14)
plt.xlabel("Strategi Pembelajaran", fontsize=12)
plt.ylabel("Jumlah Siswa", fontsize=12)

# Tampilkan plot
plt.show()
# Out:
# <ipython-input-3-15b0c06c0a83>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="LearningStrategy", data=df, palette="Blues_r")

# %% [markdown]
# Di diagram ini terlihat bahwa pola pembelajaran Minimalist memiliki jumlah siswa paling banyak dibandingkan dua pola lainnya. Hal ini menunjukkan bahwa mayoritas siswa memiliki waktu belajar yang relatif rendah dengan dukungan minimal dari bimbingan tambahan atau orang tua.
#
# Sementara itu, pola pembelajaran Intensive berada di posisi kedua, yang berarti masih ada cukup banyak siswa yang menghabiskan waktu belajar lebih lama serta mendapatkan dukungan tambahan.
#
# Di sisi lain, pola Balanced memiliki jumlah siswa paling sedikit, yang menunjukkan bahwa hanya sedikit siswa yang memiliki keseimbangan antara waktu belajar dan kegiatan ekstrakurikuler.

# %% [markdown]
# ## **Box Plot**

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='LearningStrategy', y='GPA', data=df, palette="pastel")
plt.xlabel("Strategi Pembelajaran")
plt.ylabel("GPA")
plt.title("Distribusi GPA Berdasarkan Strategi Pembelajaran")
plt.show()
# Out:
# <ipython-input-4-6293c34f167f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='LearningStrategy', y='GPA', data=df, palette="pastel")

# %% [markdown]
# Box plot di atas menggambarkan bagaimana distribusi nilai GPA (Grade Point Average) berbeda berdasarkan tiga strategi pembelajaran yang digunakan oleh siswa, yaitu Intensive, Minimalist, dan Balanced. Grafik ini membantu memahami bagaimana setiap strategi memengaruhi nilai akademik siswa secara keseluruhan.
#
# Dari grafik ini, dapat dilihat bahwa setiap strategi memiliki penyebaran nilai yang cukup luas, dengan rentang GPA yang berkisar dari 0 hingga 4. Hal ini menunjukkan bahwa ada variasi yang cukup besar dalam performa akademik siswa, terlepas dari strategi pembelajaran yang mereka gunakan.

# %% [markdown]
# ## **Pie Chart**

# %%
# Data jumlah siswa berdasarkan pola pembelajaran
labels = ['Intensive', 'Minimalist', 'Balanced']
values = [700, 1450, 250]
colors = ['#1f77b4', '#aec7e8', '#c7c7c7']

# Membuat pie chart
plt.figure(figsize=(7, 7))
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, shadow=True)
plt.title('Distribusi Strategi Pembelajaran Siswa')
plt.show()

# %% [markdown]
# Pie chart ini menunjukkan distribusi pola pembelajaran siswa dalam bentuk persentase. Dari diagram ini, terlihat bahwa mayoritas siswa menggunakan pola pembelajaran Minimalist dengan proporsi 60.4%, menunjukkan bahwa sebagian besar siswa memiliki waktu belajar mingguan yang rendah dengan minim dukungan tambahan.
#
# Sementara itu, pola pembelajaran Intensive mencakup 29.2% dari total siswa, yang berarti hampir sepertiga siswa memiliki waktu belajar yang tinggi dan mendapatkan dukungan seperti tutoring atau parental support yang kuat.
#
# Terakhir, pola pembelajaran Balanced memiliki proporsi terkecil, yaitu 10.4%, menunjukkan bahwa hanya sedikit siswa yang memiliki waktu belajar sedang dan aktif dalam kegiatan ekstrakurikuler.
#
# Dari data ini, dapat disimpulkan bahwa sebagian besar siswa cenderung memilih pola pembelajaran yang minim intensitas dan dukungan tambahan, sehingga perlu adanya strategi untuk meningkatkan efektivitas pembelajaran bagi kelompok ini.

# %% [markdown]
# ## **Tindakan yang Dapat Diambil**

# %% [markdown]
# 1. Optimalisasi Metode Pembelajaran
#
# Untuk siswa dengan pola Minimalist, materi dapat disajikan dalam bentuk yang lebih singkat dan langsung ke inti pembelajaran, seperti melalui materi ringkas atau konten berbasis modul mandiri. Sementara itu, siswa dengan pola Intensive bisa diberikan tugas tambahan atau proyek berbasis eksplorasi untuk mendukung gaya belajar mereka.
#
# 2. Pengembangan Kurikulum yang Fleksibel
#
# Institusi pendidikan dapat mempertimbangkan kurikulum yang lebih fleksibel, yang memungkinkan siswa memilih metode belajar yang paling sesuai dengan kebutuhan mereka. Misalnya, menawarkan kelas dengan format self-paced learning atau hybrid learning untuk mengakomodasi berbagai strategi pembelajaran.
#
# 3. Pemberian Dukungan Pembelajaran yang Lebih Personal
#
# Pendekatan pembelajaran dapat disesuaikan dengan karakteristik masing-masing siswa. Misalnya, siswa dengan pola Minimalist dapat diberikan akses ke materi esensial yang lebih terstruktur, sedangkan siswa dengan pola Balanced dapat dibantu untuk mengoptimalkan waktu belajar mereka agar lebih efektif.

# %% [markdown]
# ## **Kesimpulan**

# %% [markdown]
# Berdasarkan hasil analisis distribusi pola pembelajaran siswa, mayoritas siswa cenderung memiliki pola Minimalist, diikuti oleh Intensive, dan yang paling sedikit adalah Balanced. Hal ini menunjukkan bahwa sebagian besar siswa lebih memilih strategi pembelajaran yang sederhana dan efisien dibandingkan dengan pendekatan yang lebih mendalam atau seimbang.
#
# Dengan memahami distribusi ini, institusi pendidikan dapat mengadaptasi strategi pembelajaran yang lebih sesuai dengan kebutuhan siswa. Misalnya, menyediakan materi yang lebih ringkas dan terfokus untuk siswa Minimalist, memberikan tantangan tambahan untuk siswa Intensive, serta mendorong metode belajar yang lebih seimbang agar lebih banyak siswa bisa mengadopsi pola Balanced.
#
# Dengan menyesuaikan metode pembelajaran berdasarkan pola yang telah diidentifikasi, diharapkan performa akademik siswa dapat meningkat secara optimal sesuai dengan gaya belajar mereka masing-masing.
